# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import openpyxl

# %%
df = pd.read_excel('D:\DataSci\Resources\Canada.xlsx', skiprows=range(20), skipfooter=2, sheet_name='Canada by Citizenship' )

# %%
df.head(5)
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.rename(columns={'OdName':'Country','AreaName':'Continent'}, inplace=True)

# %%
df.head(5)
# Out:
#          Type    Coverage         Country  AREA Continent   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935      Asia  5501
# 1  Immigrants  Foreigners         Albania   908    Europe   925
# 2  Immigrants  Foreigners         Algeria   903    Africa   912
# 3  Immigrants  Foreigners  American Samoa   909   Oceania   957
# 4  Immigrants  Foreigners         Andorra   908    Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df.set_index('Country', inplace=True)

# %%
df.head(5)
# Out:
#                       Type    Coverage  AREA Continent   REG          RegName  \
# Country
# Afghanistan     Immigrants  Foreigners   935      Asia  5501    Southern Asia
# Albania         Immigrants  Foreigners   908    Europe   925  Southern Europe
# Algeria         Immigrants  Foreigners   903    Africa   912  Northern Africa
# American Samoa  Immigrants  Foreigners   909   Oceania   957        Polynesia
# Andorra         Immigrants  Foreigners   908    Europe   925  Southern Europe
#
#                 DEV             DevName  1980  1981  ...  2004  2005  2006  \
# Country                                              ...
# Afghanistan     902  Developing regions    16    39  ...  2978  3436  3009
# Albania         901   Developed regions     1     0  ...  1450  1223   856
# Algeria         902  Developing regions    80    67  ...  3616  3626  4807
# American Samoa  902  Developing regions     0     1  ...     0     0     1
# ...

# %%
df.columns
# Out:
# Index([     'Type',  'Coverage',      'AREA', 'Continent',       'REG',
#          'RegName',       'DEV',   'DevName',        1980,        1981,
#               1982,        1983,        1984,        1985,        1986,
#               1987,        1988,        1989,        1990,        1991,
#               1992,        1993,        1994,        1995,        1996,
#               1997,        1998,        1999,        2000,        2001,
#               2002,        2003,        2004,        2005,        2006,
#               2007,        2008,        2009,        2010,        2011,
#               2012,        2013],
#       dtype='object')

# %%
df.drop(columns ={'Type',  'Coverage','AREA','REG',
         'RegName',       'DEV',   'DevName',}, inplace=True)

# %%
df.head(5)
# Out:
#                Continent  1980  1981  1982  1983  1984  1985  1986  1987  \
# Country
# Afghanistan         Asia    16    39    39    47    71   340   496   741
# Albania           Europe     1     0     0     0     0     0     1     2
# Algeria           Africa    80    67    71    69    63    44    69   132
# American Samoa   Oceania     0     1     0     0     0     0     0     1
# Andorra           Europe     0     0     0     0     0     0     2     0
#
#                 1988  ...  2004  2005  2006  2007  2008  2009  2010  2011  \
# Country               ...
# Afghanistan      828  ...  2978  3436  3009  2652  2111  1746  1758  2203
# Albania            2  ...  1450  1223   856   702   560   716   561   539
# Algeria          242  ...  3616  3626  4807  3623  4005  5393  4752  4325
# American Samoa     0  ...     0     0     1     0     0     0     0     0
# Andorra            0  ...     0     0     1     1     0     0     0     0
#
#                 2012  2013
# Country
# ...

# %%
df['Total'] = df[range(1980,2014)].sum(axis=1)

# %%
df.head(5)
# Out:
#                Continent  1980  1981  1982  1983  1984  1985  1986  1987  \
# Country
# Afghanistan         Asia    16    39    39    47    71   340   496   741
# Albania           Europe     1     0     0     0     0     0     1     2
# Algeria           Africa    80    67    71    69    63    44    69   132
# American Samoa   Oceania     0     1     0     0     0     0     0     1
# Andorra           Europe     0     0     0     0     0     0     2     0
#
#                 1988  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# Country               ...
# Afghanistan      828  ...  3436  3009  2652  2111  1746  1758  2203  2635
# Albania            2  ...  1223   856   702   560   716   561   539   620
# Algeria          242  ...  3626  4807  3623  4005  5393  4752  4325  3774
# American Samoa     0  ...     0     1     0     0     0     0     0     0
# Andorra            0  ...     0     1     1     0     0     0     0     1
#
#                 2013  Total
# Country
# ...

# %%
df_cont = df.groupby('Continent').sum()

# %%
df_cont.head(5)
# Out:
#                                   1980   1981   1982   1983   1984   1985  \
# Continent
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
#
#                                   1986   1987   1988   1989  ...    2005  \
# Continent                                                    ...
# Africa                            3782   7494   7552   9894  ...   27523
# Asia                             28739  43203  47454  60256  ...  159253
# Europe                           24370  46698  54726  60893  ...   35955
# Latin America and the Caribbean  21179  28471  21924  25060  ...   24747
# Northern America                  7074   7705   6469   6790  ...    8394
#
# ...

# %%
exp_list =[0.1, 0, 0, 0, 0.1, 0.1]
df_cont['Total'].plot(kind='pie',figsize=(6,6), autopct='%1.1f%%', startangle=90,shadow=True,explode=exp_list)
# Out:
# <Axes: ylabel='Total'>

# %%
eighties = range(1980,1990)
nineties = range(1990,2000)
twothous = range(2000,2014)

# %%
df = df.sort_values(by='Total', ascending=False).head(15)
df_80 = df[eighties]
df_90 = df[nineties]
df_20 = df[twothous]

# %%
df_80['Total'] = df_80[eighties].sum(axis=1)
df_90['Total'] = df_90[nineties].sum(axis=1)
df_20['Total'] = df_20[twothous].sum(axis=1)

# %%
new_df = pd.concat([df_80['Total'], df_90['Total'], df_20['Total']], axis=1)

# %%
new_df.head(5)
new_df.columns = ['80s', '90s', '2000s']

# %%
new_df.head(5)
# Out:
#                                                        80s     90s   2000s
# Country
# India                                                82154  180395  429355
# China                                                32003  161528  466431
# United Kingdom of Great Britain and Northern Ir...  179171  261966  110363
# Philippines                                          60764  138482  312145
# Pakistan                                             10591   65302  165707

# %%
new_df.head(15)
# Out:
#                                                        80s     90s   2000s
# Country
# India                                                82154  180395  429355
# China                                                32003  161528  466431
# United Kingdom of Great Britain and Northern Ir...  179171  261966  110363
# Philippines                                          60764  138482  312145
# Pakistan                                             10591   65302  165707
# United States of America                             76824   56915  107383
# Iran (Islamic Republic of)                           21477   54871   99575
# Sri Lanka                                            14796   70421   63141
# Republic of Korea                                    16259   38189   88133
# Poland                                               57602   64864   16775
# Lebanon                                              24918   49245   41196
# ...

# %%
new_df.plot(kind='box')
# Out:
# <Axes: >
