# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import prettytable
# %matplotlib inline
# %load_ext sql
prettytable.DEFAULT = 'DEFAULT'

# %%
con = sqlite3.connect("RealWorldData.db")
cur = con.cursor()
# %sql sqlite:///RealWorldData.db

# %%
df = pd.read_csv('D:\DataSci\Resources\ChicagoPublicSchools.csv')
df.to_sql("CHICAGO_PUBLIC_SCHOOLS_DATA", con, if_exists='replace')
# Out:
# 566

# %%
# %sql SELECT name FROM sqlite_master WHERE type='table'
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('CHICAGO_PUBLIC_SCHOOLS_DATA',)]

# %%
# %sql SELECT count(name) FROM PRAGMA_TABLE_INFO('CHICAGO_PUBLIC_SCHOOLS_DATA');
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(79,)]

# %%
# %sql SELECT name,type,length(type) FROM PRAGMA_TABLE_INFO('CHICAGO_PUBLIC_SCHOOLS_DATA');
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('index', 'INTEGER', 7),
#  ('School_ID', 'INTEGER', 7),
#  ('NAME_OF_SCHOOL', 'TEXT', 4),
#  ('Elementary, Middle, or High School', 'TEXT', 4),
#  ('Street_Address', 'TEXT', 4),
#  ('City', 'TEXT', 4),
#  ('State', 'TEXT', 4),
#  ('ZIP_Code', 'INTEGER', 7),
#  ('Phone_Number', 'TEXT', 4),
#  ('Link', 'TEXT', 4),
#  ('Network_Manager', 'TEXT', 4),
#  ('Collaborative_Name', 'TEXT', 4),
#  ('Adequate_Yearly_Progress_Made_', 'TEXT', 4),
#  ('Track_Schedule', 'TEXT', 4),
#  ('CPS_Performance_Policy_Status', 'TEXT', 4),
#  ('CPS_Performance_Policy_Level', 'TEXT', 4),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'TEXT', 4),
#  ('Safety_Icon', 'TEXT', 4),
#  ('SAFETY_SCORE', 'REAL', 4),
#  ('Family_Involvement_Icon', 'TEXT', 4),
#  ('Family_Involvement_Score', 'TEXT', 4),
#  ('Environment_Icon', 'TEXT', 4),
#  ('Environment_Score', 'REAL', 4),
#  ('Instruction_Icon', 'TEXT', 4),
#  ('Instruction_Score', 'REAL', 4),
#  ('Leaders_Icon', 'TEXT', 4),
# ...

# %%
# %sql SELECT COUNT(DISTINCT(School_ID)) from CHICAGO_PUBLIC_SCHOOLS_DATA;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(566,)]

# %%
# %%sql
# SELECT MAX(SAFETY_SCORE) from CHICAGO_PUBLIC_SCHOOLS_DATA;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(99.0,)]

# %%
# %%sql
# SELECT NAME_OF_SCHOOL, School_ID from CHICAGO_PUBLIC_SCHOOLS_DATA where
# SAFETY_SCORE = (SELECT MAX(SAFETY_SCORE) from CHICAGO_PUBLIC_SCHOOLS_DATA);
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('Abraham Lincoln Elementary School', 610038),
#  ('Alexander Graham Bell Elementary School', 609799),
#  ('Annie Keller Elementary Gifted Magnet School', 610084),
#  ('Augustus H Burley Elementary School', 609820),
#  ('Edgar Allan Poe Elementary Classical School', 610132),
#  ('Edgebrook Elementary School', 609901),
#  ('Ellen Mitchell Elementary School', 610073),
#  ('James E McDade Elementary Classical School', 610066),
#  ('James G Blaine Elementary School', 609803),
#  ('LaSalle Elementary Language Academy', 610033),
#  ('Mary E Courtenay Elementary Language Arts Center', 610355),
#  ('Northside College Preparatory High School', 609749),
#  ('Northside Learning Center High School', 609744),
#  ('Norwood Park Elementary School', 610099),
#  ('Oriole Park Elementary School', 610105),
#  ('Sauganash Elementary School', 610155),
#  ('Stephen Decatur Classical Elementary School', 609880),
#  ('Talman Elementary School', 610249),
# ...

# %%
# %%sql
# SELECT NAME_OF_SCHOOL, School_ID from CHICAGO_PUBLIC_SCHOOLS_DATA
# ORDER BY AVERAGE_STUDENT_ATTENDANCE DESC
# LIMIT 10;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [('John Charles Haines Elementary School', 609959),
#  ('James Ward Elementary School', 610217),
#  ('Edgar Allan Poe Elementary Classical School', 610132),
#  ('Orozco Fine Arts & Sciences Elementary School', 610329),
#  ('Rachel Carson Elementary School', 609842),
#  ('Annie Keller Elementary Gifted Magnet School', 610084),
#  ('Andrew Jackson Elementary Language Academy', 610060),
#  ('Lenart Elementary Regional Gifted Center', 610298),
#  ('Disney II Magnet School', 610515),
#  ('John H Vanderpoel Elementary Magnet School', 610207)]

# %%
# %%sql
# SELECT SUM(COLLEGE_ENROLLMENT) AS TOTAL_ENROLLMENT, COMMUNITY_AREA_NAME from CHICAGO_PUBLIC_SCHOOLS_DATA
# GROUP BY COMMUNITY_AREA_NAME;
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(6864, 'ALBANY PARK'),
#  (4823, 'ARCHER HEIGHTS'),
#  (1458, 'ARMOUR SQUARE'),
#  (6483, 'ASHBURN'),
#  (4175, 'AUBURN GRESHAM'),
#  (10933, 'AUSTIN'),
#  (1522, 'AVALON PARK'),
#  (3640, 'AVONDALE'),
#  (14386, 'BELMONT CRAGIN'),
#  (1636, 'BEVERLY'),
#  (3167, 'BRIDGEPORT'),
#  (9647, 'BRIGHTON PARK'),
#  (549, 'BURNSIDE'),
#  (1568, 'CALUMET HEIGHTS'),
#  (5042, 'CHATHAM'),
#  (7086, 'CHICAGO LAWN'),
#  (2085, 'CLEARING'),
#  (4670, 'DOUGLAS'),
#  (4568, 'DUNNING'),
#  (5337, 'EAST GARFIELD PARK'),
#  (5305, 'EAST SIDE'),
#  (4600, 'EDGEWATER'),
#  (910, 'EDISON PARK'),
#  (6832, 'ENGLEWOOD'),
#  (1431, 'FOREST GLEN'),
#  (531, 'FULLER PARK'),
#  (9915, 'GAGE PARK'),
#  (4552, 'GARFIELD RIDGE'),
#  (2809, 'GRAND BOULEVARD'),
#  (4051, 'GREATER GRAND CROSSING'),
#  (963, 'HEGEWISCH'),
#  (3975, 'HERMOSA'),
#  (8620, 'HUMBOLDT PARK'),
#  (1930, 'HYDE PARK'),
#  (7764, 'IRVING PARK'),
#  (1755, 'JEFFERSON PARK'),
#  (4287, 'KENWOOD'),
# ...
